# %%
# import libraries
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# "manually" in numpy

# the list of numbers
z = [1,2,3]

#compute the softmax result
num = np.exp(z)
den = np.sum(np.exp(z))
sigma = num / den

print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# repeat with some random integers
z = np.random.randint(-5, high=15, size=25)
print(z)

# compute the softmax result
num = np.exp(z)
den = np.sum(num)
sigma = num/den

# compare
plt.plot(z, sigma, 'ko')
plt.xlabel('Original number (z)')
plt.ylabel('Softmaxified σ')
plt.yscale('log') # softmax function is a linear transformation in log space
plt.title('Σσ = %g' %np.sum(sigma))
plt.show()
# Out:
# [ 8  6  5 -5 10  4 -3 -2  7  2  7  2  9  7 -3 13  1  1 -4  9  8 14 -5  7
#  -2]

# %% [markdown]
# ## Using pytorch

# %%
# slightly more involved using torch.nn

# create an intance of the softmax activation class
softfun = nn.Softmax(dim=0)

# then apply the data to that function
sigmaT = softfun( torch.Tensor(z) )

# now we get the results
print(sigmaT)
# Out:
# tensor([1.5989e-03, 3.2114e-02, 2.1638e-04, 3.9632e-06, 8.7294e-02, 2.3729e-01,
#         3.2114e-02, 1.0773e-05, 9.8237e-09, 1.1814e-02, 1.1814e-02, 5.3636e-07,
#         3.9632e-06, 2.3729e-01, 1.1814e-02, 2.3729e-01, 5.3636e-07, 1.3295e-09,
#         3.9632e-06, 9.8237e-09, 1.1814e-02, 7.2588e-08, 2.1638e-04, 3.6139e-09,
#         8.7294e-02])

# %%
# show that they are the same
plt.plot(sigma, sigmaT, 'ko')
plt.xlabel('"Manual" softmax')
plt.ylabel('Pytorch nn.Softmax')
plt.title(f'The two methods correlate at r={np.corrcoef(sigma,sigmaT)[0,1]}')
plt.show()
